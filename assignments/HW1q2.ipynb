# %%
using Random, Plots
import Statistics

# %% [markdown]
# # Problem 2
# Problem Statement
# >>
# Consider a random variable $Z_t$ that represents the vertical height of a micro-droplet.
#
# ### Discussion of modelling approach
# Inherintly I want to model the effect of collision forces on particles, to get changes in acceleration.
# Then acceleration can be integrated to give velocity, which can be integrated to give position.
#
# I'm going to model the position $Z_t$ as the integral of a stochastic process $Y_t$, describing the velocity of the micro_droplet.
# $Y_t$ in turn is the integral over the acceleration of the micro_droplet, represented as a stochastic process $X_t = g + \epsilon_t$.
# The constant $g$ represents the appropriately scaled acceleration due to gravity.
# By choosing $\epsilon_t \sim N(0,\eta^2)$, we end up getting a nonzero $X_t$, which leads to the downward biased velocity.
# The final integration will give the positions we care about.
#
#
#
# ## Part A
# To get an approximation of the occupational time, $\tau$, I'm going to simulate the path of a large number
# of particles from the top of the bounding box, and measure how many steps it takes for them to leave the box.
#
# There are going to be two leaving conditions:
#  - When a particle leaves the top of the box
#  - When the particle leaves the bottom of the box.
#
# ### Thoughts on computational approach
# So, I'm going compute the occupational time by simulating each particle in a while loop individually.
# Thus I'm not going to be
#
#
# ## Part B
#
# ### Thoughts on computational approach
#
#
# ## Simplifying assumptions
# I am going to rescale my coordinates in length and time, such that $g=1$ in the time period that I care about.

# %%
#Constants
const GRAVITY = 1.0
const η = 1e-1
# Out:
# invalid redefinition of constant GRAVITY
#
# Stacktrace:
#  [1] top-level scope
#    @ In[10]:2
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
#Create a struct to capture the type of exit, with a couple of helpful methods
struct ExitType
    time::Int
    exited_top::Bool
end

measured_time(exit_type::ExitType) = exit_type.time
exited_top_boundary(exit_type::ExitType) = exit_type.exited_top
exited_bottom_boundary(exit_type::ExitType) = !exit_type.exited_top
# Out:
# exited_bottom_boundary (generic function with 1 method)

# %%
test = ExitType(3,false)
measured_time(test),exited_top_boundary(test),exited_bottom_boundary(test)
# Out:
# (3, false, true)

# %%
function tick(position::Float64,velocity::Float64)
    #this takes a particle, defined by position and velocity, and adjusts each
    acceleration = GRAVITY + η*randn()
    
    velocity = velocity + acceleration
    position = position + velocity
    
    return position,velocity
end
# Out:
# tick (generic function with 1 method)

# %%
function time_in_box(lower_bound::Float64, initial_velocity::Float64)
    #this function takes a lower bound on the box and initial velocity
    #then calculates the number of steps until it leaves the box.
    position = 0.0
    velocity = initial_velocity
    counter = 0
    
    while true
        #update counter
        counter += 1
        
        #update position
        position, velocity = tick(position,velocity)
        
        # Exit conditions
        if position < lower_bound
            #if you float below the bottom boundary
            return ExitType(counter,false)
        elseif position > 0
            #if you float above the top boundary
            return ExitType(counter,true) 
        else
            continue
        end
    end
end
# Out:
# time_in_box (generic function with 1 method)

# %%
for i in 1.0:1:160
    println(-i, " ", time_in_box(-i,0.0))
end
# Out:
# -1.0 ExitType(1, true)
# -2.0 ExitType(1, true)
# -3.0 ExitType(1, true)
# -4.0 ExitType(3, true)
# -5.0 ExitType(38, false)
# -6.0 ExitType(1, true)
# -7.0 ExitType(14, false)
# -8.0 ExitType(32, false)
# -9.0 ExitType(26, false)
# -10.0 ExitType(1, true)
# -11.0 ExitType(25, false)
# -12.0 ExitType(37, true)
# -13.0 ExitType(1, true)
# -14.0 ExitType(1, true)
# -15.0 ExitType(3, true)
# -16.0 ExitType(4, true)
# -17.0 ExitType(1, true)
# -18.0 ExitType(14, true)
# -19.0 ExitType(50, false)
# -20.0 ExitType(3, true)
# -21.0 ExitType(1, true)
# -22.0 ExitType(84, true)
# -23.0 ExitType(1, true)
# -24.0 ExitType(45, true)
# -25.0 ExitType(1, true)
# -26.0 ExitType(9, true)
# -27.0 ExitType(1, true)
# -28.0 ExitType(1, true)
# -29.0 ExitType(1, true)
# -30.0 ExitType(2, true)
# -31.0 ExitType(2, true)
# -32.0 ExitType(6, true)
# -33.0 ExitType(156, false)
# -34.0 ExitType(1, true)
# -35.0 ExitType(2, true)
# -36.0 ExitType(1, true)
# -37.0 ExitType(1, true)
# -38.0 ExitType(1, true)
# -39.0 ExitType(160, true)
# -40.0 ExitType(1, true)
# -41.0 ExitType(4, true)
# -42.0 ExitType(3, true)
# -43.0 ExitType(1, true)
# -44.0 ExitType(1, true)
# -45.0 ExitType(1, true)
# -46.0 ExitType(1, true)
# -47.0 ExitType(1, true)
# -48.0 ExitType(1, true)
# -49.0 ExitType(44, true)
# -50.0 ExitType(1, true)
# -51.0 ExitType(1, true)
# -52.0 ExitType(48, false)
# -53.0 ExitType(1, true)
# -54.0 ExitType(28, true)
# -55.0 ExitType(158, true)
# -56.0 ExitType(31, true)
# -57.0 ExitType(68, false)
# -58.0 ExitType(113, false)
# -59.0 ExitType(102, false)
# -60.0 ExitType(1, true)
# -61.0 ExitType(82, true)
# -62.0 ExitType(1, true)
# -63.0 ExitType(13, true)
# -64.0 ExitType(1, true)
# -65.0 ExitType(2, true)
# -66.0 ExitType(1, true)
# -67.0 ExitType(190, true)
# -68.0 ExitType(1, true)
# -69.0 ExitType(3, true)
# -70.0 ExitType(279, true)
# -71.0 ExitType(1, true)
# -72.0 ExitType(113, false)
# -73.0 ExitType(90, false)
# -74.0 ExitType(1, true)
# -75.0 ExitType(3, true)
# -76.0 ExitType(2, true)
# -77.0 ExitType(4, true)
# -78.0 ExitType(1, true)
# -79.0 ExitType(1, true)
# -80.0 ExitType(1, true)
# -81.0 ExitType(1, true)
# -82.0 ExitType(26, true)
# -83.0 ExitType(1, true)
# -84.0 ExitType(1, true)
# -85.0 ExitType(188, false)
# -86.0 ExitType(1, true)
# -87.0 ExitType(1, true)
# -88.0 ExitType(5, true)
# -89.0 ExitType(173, false)
# -90.0 ExitType(3, true)
# -91.0 ExitType(16, true)
# -92.0 ExitType(1, true)
# -93.0 ExitType(1, true)
# -94.0 ExitType(35, true)
# -95.0 ExitType(1, true)
# -96.0 ExitType(87, false)
# -97.0 ExitType(3, true)
# -98.0 ExitType(1, true)
# -99.0 ExitType(1, true)
# -100.0 ExitType(176, false)
# -101.0 ExitType(4, true)
# -102.0 ExitType(4, true)
# -103.0 ExitType(1, true)
# -104.0 ExitType(14, true)
# -105.0 ExitType(2, true)
# -106.0 ExitType(1, true)
# -107.0 ExitType(1, true)
# -108.0 ExitType(1, true)
# -109.0 ExitType(5, true)
# -110.0 ExitType(1, true)
# -111.0 ExitType(27, true)
# -112.0 ExitType(1, true)
# -113.0 ExitType(1, true)
# -114.0 ExitType(1, true)
# -115.0 ExitType(1, true)
# -116.0 ExitType(1, true)
# -117.0 ExitType(1, true)
# -118.0 ExitType(1, true)
# -119.0 ExitType(1, true)
# -120.0 ExitType(6, true)
# -121.0 ExitType(1, true)
# -122.0 ExitType(1, true)
# -123.0 ExitType(3, true)
# -124.0 ExitType(17, true)
# -125.0 ExitType(57, true)
# -126.0 ExitType(3, true)
# -127.0 ExitType(1, true)
# -128.0 ExitType(1, true)
# -129.0 ExitType(1, true)
# -130.0 ExitType(1, true)
# -131.0 ExitType(3, true)
# -132.0 ExitType(2, true)
# -133.0 ExitType(1, true)
# -134.0 ExitType(1, true)
# -135.0 ExitType(1, true)
# -136.0 ExitType(3, true)
# -137.0 ExitType(1, true)
# -138.0 ExitType(4, true)
# -139.0 ExitType(1, true)
# -140.0 ExitType(3, true)
# -141.0 ExitType(1, true)
# -142.0 ExitType(146, true)
# -143.0 ExitType(213, true)
# -144.0 ExitType(1, true)
# -145.0 ExitType(2, true)
# -146.0 ExitType(1, true)
# -147.0 ExitType(1, true)
# -148.0 ExitType(150, false)
# -149.0 ExitType(1, true)
# -150.0 ExitType(134, false)
# -151.0 ExitType(4, true)
# -152.0 ExitType(2, true)
# -153.0 ExitType(9, true)
# -154.0 ExitType(1, true)
# -155.0 ExitType(8, true)
# -156.0 ExitType(1, true)
# -157.0 ExitType(1, true)
# -158.0 ExitType(1, true)
# -159.0 ExitType(1, true)
# -160.0 ExitType(1, true)

# %%
for i in 1:1600
    sim =time_in_box(-1.0,0.0)
    if exited_top_boundary(sim)
        println(i, " ", sim)
    end
end
# Out:
# 2 ExitType(1, true)
# 4 ExitType(2, true)
# 8 ExitType(17, true)
# 9 ExitType(1, true)
# 10 ExitType(2, true)
# 12 ExitType(1, true)
# 13 ExitType(12, true)
# 14 ExitType(7, true)
# 15 ExitType(1, true)
# 16 ExitType(8, true)
# 18 ExitType(1, true)
# 19 ExitType(1, true)
# 21 ExitType(1, true)
# 22 ExitType(6, true)
# 23 ExitType(1, true)
# 24 ExitType(1, true)
# 25 ExitType(1, true)
# 26 ExitType(1, true)
# 29 ExitType(2, true)
# 31 ExitType(8, true)
# 32 ExitType(1, true)
# 33 ExitType(1, true)
# 34 ExitType(1, true)
# 35 ExitType(1, true)
# 36 ExitType(1, true)
# 37 ExitType(1, true)
# 38 ExitType(5, true)
# 40 ExitType(1, true)
# 41 ExitType(1, true)
# 42 ExitType(3, true)
# 43 ExitType(1, true)
# 46 ExitType(4, true)
# 47 ExitType(2, true)
# 48 ExitType(1, true)
# 49 ExitType(2, true)
# 51 ExitType(1, true)
# 53 ExitType(1, true)
# 54 ExitType(1, true)
# 56 ExitType(9, true)
# 57 ExitType(1, true)
# 58 ExitType(1, true)
# 60 ExitType(1, true)
# 61 ExitType(18, true)
# 62 ExitType(1, true)
# 63 ExitType(2, true)
# 64 ExitType(1, true)
# 65 ExitType(1, true)
# 66 ExitType(1, true)
# 67 ExitType(1, true)
# 68 ExitType(8, true)
# 69 ExitType(1, true)
# 70 ExitType(1, true)
# 71 ExitType(1, true)
# 72 ExitType(1, true)
# 73 ExitType(1, true)
# 74 ExitType(1, true)
# 75 ExitType(2, true)
# 76 ExitType(16, true)
# 77 ExitType(1, true)
# 78 ExitType(5, true)
# 79 ExitType(1, true)
# 81 ExitType(1, true)
# 82 ExitType(1, true)
# 85 ExitType(1, true)
# 86 ExitType(1, true)
# 87 ExitType(1, true)
# 88 ExitType(1, true)
# 89 ExitType(1, true)
# 91 ExitType(1, true)
# 92 ExitType(1, true)
# 93 ExitType(1, true)
# 94 ExitType(1, true)
# 95 ExitType(1, true)
# 96 ExitType(1, true)
# 97 ExitType(1, true)
# 98 ExitType(1, true)
# 99 ExitType(1, true)
# 100 ExitType(1, true)
# 101 ExitType(6, true)
# 102 ExitType(1, true)
# 103 ExitType(1, true)
# 104 ExitType(1, true)
# 105 ExitType(1, true)
# 106 ExitType(5, true)
# 107 ExitType(2, true)
# 108 ExitType(1, true)
# 110 ExitType(1, true)
# 111 ExitType(1, true)
# 112 ExitType(1, true)
# 113 ExitType(4, true)
# 114 ExitType(13, true)
# 117 ExitType(3, true)
# 119 ExitType(1, true)
# 120 ExitType(1, true)
# 121 ExitType(1, true)
# 122 ExitType(1, true)
# 123 ExitType(1, true)
# 124 ExitType(5, true)
# 125 ExitType(1, true)
# 126 ExitType(13, true)
# 127 ExitType(1, true)
# 128 ExitType(1, true)
# 129 ExitType(1, true)
# 130 ExitType(3, true)
# 131 ExitType(5, true)
# 132 ExitType(1, true)
# 134 ExitType(1, true)
# 136 ExitType(1, true)
# 138 ExitType(1, true)
# 139 ExitType(1, true)
# 140 ExitType(1, true)
# 142 ExitType(1, true)
# 143 ExitType(2, true)
# 144 ExitType(3, true)
# 145 ExitType(1, true)
# 146 ExitType(14, true)
# 147 ExitType(1, true)
# 148 ExitType(1, true)
# 149 ExitType(1, true)
# 150 ExitType(1, true)
# 152 ExitType(1, true)
# 153 ExitType(1, true)
# 154 ExitType(1, true)
# 155 ExitType(1, true)
# 156 ExitType(2, true)
# 158 ExitType(1, true)
# 159 ExitType(2, true)
# 160 ExitType(1, true)
# 161 ExitType(1, true)
# 162 ExitType(1, true)
# 164 ExitType(1, true)
# 166 ExitType(12, true)
# 167 ExitType(2, true)
# 169 ExitType(1, true)
# 170 ExitType(2, true)
# 171 ExitType(10, true)
# 172 ExitType(1, true)
# 173 ExitType(1, true)
# 174 ExitType(1, true)
# 175 ExitType(4, true)
# 176 ExitType(3, true)
# 177 ExitType(1, true)
# 179 ExitType(1, true)
# 180 ExitType(1, true)
# 182 ExitType(2, true)
# 183 ExitType(11, true)
# 185 ExitType(1, true)
# 186 ExitType(1, true)
# 187 ExitType(1, true)
# 188 ExitType(2, true)
# 191 ExitType(1, true)
# 192 ExitType(17, true)
# 194 ExitType(1, true)
# 195 ExitType(1, true)
# 196 ExitType(1, true)
# 197 ExitType(1, true)
# 198 ExitType(1, true)
# 199 ExitType(1, true)
# 201 ExitType(4, true)
# 202 ExitType(2, true)
# 203 ExitType(6, true)
# 205 ExitType(10, true)
# 206 ExitType(1, true)
# 208 ExitType(3, true)
# 211 ExitType(1, true)
# 212 ExitType(1, true)
# 213 ExitType(1, true)
# 214 ExitType(1, true)
# 215 ExitType(1, true)
# 216 ExitType(2, true)
# 218 ExitType(3, true)
# 219 ExitType(1, true)
# 220 ExitType(1, true)
# 222 ExitType(2, true)
# 224 ExitType(4, true)
# 225 ExitType(1, true)
# 226 ExitType(2, true)
# 228 ExitType(1, true)
# 229 ExitType(10, true)
# 230 ExitType(2, true)
# 231 ExitType(1, true)
# 233 ExitType(3, true)
# 234 ExitType(1, true)
# 235 ExitType(1, true)
# 237 ExitType(1, true)
# 238 ExitType(1, true)
# 240 ExitType(4, true)
# 241 ExitType(1, true)
# 242 ExitType(1, true)
# 243 ExitType(1, true)
# 246 ExitType(1, true)
# 247 ExitType(1, true)
# 248 ExitType(1, true)
# 249 ExitType(2, true)
# 250 ExitType(1, true)
# 252 ExitType(1, true)
# 254 ExitType(1, true)
# 255 ExitType(1, true)
# 256 ExitType(1, true)
# 257 ExitType(1, true)
# 258 ExitType(1, true)
# 260 ExitType(3, true)
# 261 ExitType(1, true)
# 262 ExitType(2, true)
# 263 ExitType(10, true)
# 264 ExitType(1, true)
# 265 ExitType(15, true)
# 266 ExitType(1, true)
# 267 ExitType(1, true)
# 268 ExitType(1, true)
# 269 ExitType(1, true)
# 272 ExitType(3, true)
# 273 ExitType(2, true)
# 274 ExitType(1, true)
# 275 ExitType(2, true)
# 276 ExitType(1, true)
# 278 ExitType(10, true)
# 279 ExitType(1, true)
# 280 ExitType(1, true)
# 281 ExitType(1, true)
# 284 ExitType(1, true)
# 285 ExitType(1, true)
# 286 ExitType(1, true)
# 287 ExitType(1, true)
# 288 ExitType(1, true)
# 291 ExitType(1, true)
# 292 ExitType(1, true)
# 293 ExitType(1, true)
# 294 ExitType(1, true)
# 297 ExitType(1, true)
# 299 ExitType(7, true)
# 300 ExitType(1, true)
# 301 ExitType(3, true)
# 302 ExitType(1, true)
# 303 ExitType(2, true)
# 304 ExitType(1, true)
# 305 ExitType(5, true)
# 306 ExitType(10, true)
# 307 ExitType(1, true)
# 308 ExitType(1, true)
# 309 ExitType(1, true)
# 310 ExitType(14, true)
# 311 ExitType(1, true)
# 313 ExitType(1, true)
# 314 ExitType(18, true)
# 316 ExitType(4, true)
# 318 ExitType(1, true)
# 319 ExitType(1, true)
# 320 ExitType(3, true)
# 321 ExitType(1, true)
# 322 ExitType(11, true)
# 323 ExitType(3, true)
# 325 ExitType(1, true)
# 326 ExitType(9, true)
# 330 ExitType(1, true)
# 333 ExitType(19, true)
# 334 ExitType(13, true)
# 336 ExitType(1, true)
# 337 ExitType(1, true)
# 341 ExitType(1, true)
# 344 ExitType(6, true)
# 345 ExitType(1, true)
# 346 ExitType(3, true)
# 347 ExitType(1, true)
# 348 ExitType(27, true)
# 349 ExitType(1, true)
# 351 ExitType(2, true)
# 352 ExitType(2, true)
# 356 ExitType(1, true)
# 357 ExitType(3, true)
# 358 ExitType(1, true)
# 359 ExitType(2, true)
# 360 ExitType(1, true)
# 361 ExitType(1, true)
# 362 ExitType(1, true)
# 363 ExitType(1, true)
# 365 ExitType(3, true)
# 366 ExitType(1, true)
# 367 ExitType(1, true)
# 368 ExitType(2, true)
# 370 ExitType(10, true)
# 373 ExitType(1, true)
# 374 ExitType(1, true)
# 375 ExitType(1, true)
# 376 ExitType(3, true)
# 378 ExitType(1, true)
# 379 ExitType(1, true)
# 380 ExitType(2, true)
# 382 ExitType(1, true)
# 383 ExitType(1, true)
# 385 ExitType(1, true)
# 386 ExitType(12, true)
# 387 ExitType(1, true)
# 388 ExitType(2, true)
# 389 ExitType(11, true)
# 390 ExitType(1, true)
# 393 ExitType(1, true)
# 394 ExitType(1, true)
# 395 ExitType(1, true)
# 397 ExitType(1, true)
# 398 ExitType(3, true)
# 399 ExitType(2, true)
# 400 ExitType(1, true)
# 401 ExitType(1, true)
# 402 ExitType(2, true)
# 403 ExitType(3, true)
# 404 ExitType(1, true)
# 405 ExitType(1, true)
# 406 ExitType(1, true)
# 407 ExitType(1, true)
# 408 ExitType(1, true)
# 409 ExitType(1, true)
# 412 ExitType(1, true)
# 414 ExitType(7, true)
# 415 ExitType(2, true)
# 417 ExitType(1, true)
# 418 ExitType(9, true)
# 421 ExitType(11, true)
# 422 ExitType(1, true)
# 423 ExitType(1, true)
# 425 ExitType(1, true)
# 426 ExitType(1, true)
# 427 ExitType(1, true)
# 428 ExitType(2, true)
# 429 ExitType(21, true)
# 431 ExitType(9, true)
# 432 ExitType(8, true)
# 433 ExitType(1, true)
# 434 ExitType(1, true)
# 436 ExitType(1, true)
# 437 ExitType(1, true)
# 438 ExitType(1, true)
# 439 ExitType(1, true)
# 440 ExitType(2, true)
# 441 ExitType(3, true)
# 442 ExitType(1, true)
# 443 ExitType(1, true)
# 444 ExitType(1, true)
# 446 ExitType(1, true)
# 447 ExitType(2, true)
# 448 ExitType(1, true)
# 449 ExitType(14, true)
# 450 ExitType(1, true)
# 451 ExitType(1, true)
# 452 ExitType(1, true)
# 453 ExitType(2, true)
# 454 ExitType(3, true)
# 455 ExitType(1, true)
# 456 ExitType(2, true)
# 457 ExitType(1, true)
# 458 ExitType(3, true)
# 459 ExitType(2, true)
# 464 ExitType(1, true)
# 465 ExitType(1, true)
# 466 ExitType(2, true)
# 467 ExitType(5, true)
# 469 ExitType(3, true)
# 470 ExitType(1, true)
# 471 ExitType(1, true)
# 472 ExitType(1, true)
# 473 ExitType(1, true)
# 474 ExitType(1, true)
# 475 ExitType(9, true)
# 476 ExitType(4, true)
# 477 ExitType(1, true)
# 479 ExitType(1, true)
# 480 ExitType(5, true)
# 481 ExitType(1, true)
# 482 ExitType(2, true)
# 483 ExitType(1, true)
# 484 ExitType(1, true)
# 485 ExitType(1, true)
# 486 ExitType(2, true)
# 487 ExitType(1, true)
# 488 ExitType(6, true)
# 489 ExitType(1, true)
# 490 ExitType(1, true)
# 491 ExitType(1, true)
# 492 ExitType(1, true)
# 493 ExitType(1, true)
# 494 ExitType(1, true)
# 495 ExitType(6, true)
# 496 ExitType(4, true)
# 500 ExitType(1, true)
# 501 ExitType(1, true)
# 502 ExitType(1, true)
# 503 ExitType(6, true)
# 504 ExitType(1, true)
# 505 ExitType(1, true)
# 506 ExitType(1, true)
# 507 ExitType(1, true)
# 508 ExitType(1, true)
# 510 ExitType(1, true)
# 511 ExitType(1, true)
# 512 ExitType(2, true)
# 514 ExitType(4, true)
# 517 ExitType(1, true)
# 520 ExitType(12, true)
# 521 ExitType(1, true)
# 522 ExitType(1, true)
# 523 ExitType(1, true)
# 524 ExitType(1, true)
# 526 ExitType(1, true)
# 527 ExitType(1, true)
# 528 ExitType(1, true)
# 529 ExitType(2, true)
# 531 ExitType(15, true)
# 533 ExitType(1, true)
# 534 ExitType(1, true)
# 535 ExitType(13, true)
# 536 ExitType(1, true)
# 537 ExitType(1, true)
# 538 ExitType(1, true)
# 539 ExitType(1, true)
# 541 ExitType(2, true)
# 542 ExitType(13, true)
# 543 ExitType(1, true)
# 545 ExitType(1, true)
# 548 ExitType(1, true)
# 550 ExitType(8, true)
# 551 ExitType(1, true)
# 552 ExitType(1, true)
# 553 ExitType(2, true)
# 555 ExitType(4, true)
# 556 ExitType(6, true)
# 557 ExitType(8, true)
# 558 ExitType(1, true)
# 559 ExitType(1, true)
# 560 ExitType(1, true)
# 561 ExitType(2, true)
# 562 ExitType(2, true)
# 563 ExitType(1, true)
# 565 ExitType(2, true)
# 566 ExitType(1, true)
# 568 ExitType(3, true)
# 570 ExitType(1, true)
# 571 ExitType(1, true)
# 572 ExitType(1, true)
# 573 ExitType(2, true)
# 574 ExitType(1, true)
# 575 ExitType(1, true)
# 576 ExitType(5, true)
# 578 ExitType(1, true)
# 579 ExitType(1, true)
# 580 ExitType(1, true)
# 581 ExitType(1, true)
# 582 ExitType(1, true)
# 583 ExitType(1, true)
# 584 ExitType(3, true)
# 586 ExitType(1, true)
# 587 ExitType(1, true)
# 589 ExitType(13, true)
# 591 ExitType(1, true)
# 593 ExitType(5, true)
# 594 ExitType(1, true)
# 596 ExitType(2, true)
# 597 ExitType(1, true)
# 599 ExitType(1, true)
# 600 ExitType(1, true)
# 601 ExitType(2, true)
# 602 ExitType(1, true)
# 604 ExitType(3, true)
# 605 ExitType(1, true)
# 606 ExitType(1, true)
# 608 ExitType(2, true)
# 609 ExitType(1, true)
# 610 ExitType(1, true)
# 611 ExitType(2, true)
# 612 ExitType(1, true)
# 613 ExitType(1, true)
# 615 ExitType(1, true)
# 616 ExitType(1, true)
# 617 ExitType(1, true)
# 618 ExitType(1, true)
# 619 ExitType(3, true)
# 624 ExitType(1, true)
# 625 ExitType(1, true)
# 627 ExitType(1, true)
# 628 ExitType(1, true)
# 629 ExitType(2, true)
# 633 ExitType(1, true)
# 634 ExitType(13, true)
# 636 ExitType(1, true)
# 637 ExitType(6, true)
# 638 ExitType(2, true)
# 641 ExitType(1, true)
# 642 ExitType(6, true)
# 643 ExitType(1, true)
# 644 ExitType(5, true)
# 645 ExitType(3, true)
# 646 ExitType(1, true)
# 648 ExitType(1, true)
# 651 ExitType(1, true)
# 654 ExitType(5, true)
# 655 ExitType(1, true)
# 656 ExitType(4, true)
# 657 ExitType(1, true)
# 658 ExitType(1, true)
# 659 ExitType(1, true)
# 660 ExitType(1, true)
# 661 ExitType(1, true)
# 662 ExitType(1, true)
# 664 ExitType(1, true)
# 665 ExitType(3, true)
# 667 ExitType(2, true)
# 668 ExitType(1, true)
# 669 ExitType(2, true)
# 670 ExitType(1, true)
# 671 ExitType(1, true)
# 672 ExitType(1, true)
# 673 ExitType(1, true)
# 674 ExitType(1, true)
# 675 ExitType(15, true)
# 677 ExitType(2, true)
# 678 ExitType(1, true)
# 679 ExitType(1, true)
# 680 ExitType(1, true)
# 682 ExitType(8, true)
# 683 ExitType(1, true)
# 684 ExitType(1, true)
# 686 ExitType(1, true)
# 688 ExitType(1, true)
# 689 ExitType(12, true)
# 690 ExitType(1, true)
# 691 ExitType(1, true)
# 692 ExitType(1, true)
# 693 ExitType(2, true)
# 694 ExitType(1, true)
# 695 ExitType(1, true)
# 696 ExitType(2, true)
# 697 ExitType(12, true)
# 698 ExitType(1, true)
# 699 ExitType(1, true)
# 700 ExitType(1, true)
# 702 ExitType(1, true)
# 703 ExitType(2, true)
# 704 ExitType(2, true)
# 705 ExitType(4, true)
# 706 ExitType(1, true)
# 707 ExitType(1, true)
# 708 ExitType(1, true)
# 709 ExitType(1, true)
# 710 ExitType(1, true)
# 711 ExitType(1, true)
# 712 ExitType(2, true)
# 713 ExitType(1, true)
# 715 ExitType(2, true)
# 717 ExitType(2, true)
# 718 ExitType(1, true)
# 719 ExitType(5, true)
# 721 ExitType(1, true)
# 722 ExitType(1, true)
# 724 ExitType(1, true)
# 725 ExitType(1, true)
# 726 ExitType(1, true)
# 727 ExitType(3, true)
# 728 ExitType(1, true)
# 732 ExitType(1, true)
# 733 ExitType(1, true)
# 734 ExitType(3, true)
# 735 ExitType(1, true)
# 737 ExitType(1, true)
# 738 ExitType(2, true)
# 740 ExitType(1, true)
# 741 ExitType(9, true)
# 742 ExitType(1, true)
# 743 ExitType(1, true)
# 744 ExitType(1, true)
# 746 ExitType(1, true)
# 747 ExitType(1, true)
# 748 ExitType(1, true)
# 749 ExitType(1, true)
# 750 ExitType(1, true)
# 751 ExitType(1, true)
# 752 ExitType(1, true)
# 753 ExitType(1, true)
# 754 ExitType(1, true)
# 755 ExitType(1, true)
# 757 ExitType(1, true)
# 758 ExitType(1, true)
# 760 ExitType(14, true)
# 761 ExitType(1, true)
# 762 ExitType(3, true)
# 763 ExitType(1, true)
# 764 ExitType(1, true)
# 766 ExitType(1, true)
# 767 ExitType(1, true)
# 768 ExitType(1, true)
# 769 ExitType(1, true)
# 770 ExitType(1, true)
# 771 ExitType(1, true)
# 772 ExitType(1, true)
# 774 ExitType(11, true)
# 776 ExitType(1, true)
# 777 ExitType(1, true)
# 778 ExitType(1, true)
# 779 ExitType(1, true)
# 780 ExitType(1, true)
# 781 ExitType(2, true)
# 782 ExitType(1, true)
# 783 ExitType(14, true)
# 784 ExitType(3, true)
# 785 ExitType(1, true)
# 786 ExitType(1, true)
# 787 ExitType(1, true)
# 789 ExitType(2, true)
# 791 ExitType(1, true)
# 792 ExitType(3, true)
# 793 ExitType(4, true)
# 794 ExitType(2, true)
# 796 ExitType(1, true)
# 797 ExitType(1, true)
# 798 ExitType(1, true)
# 799 ExitType(1, true)
# 800 ExitType(3, true)
# 801 ExitType(1, true)
# 802 ExitType(1, true)
# 803 ExitType(1, true)
# 805 ExitType(3, true)
# 808 ExitType(1, true)
# 809 ExitType(1, true)
# 810 ExitType(1, true)
# 811 ExitType(1, true)
# 815 ExitType(1, true)
# 817 ExitType(5, true)
# 819 ExitType(1, true)
# 821 ExitType(1, true)
# 823 ExitType(8, true)
# 825 ExitType(12, true)
# 826 ExitType(1, true)
# 828 ExitType(1, true)
# 829 ExitType(1, true)
# 830 ExitType(1, true)
# 831 ExitType(1, true)
# 833 ExitType(6, true)
# 834 ExitType(1, true)
# 835 ExitType(2, true)
# 836 ExitType(13, true)
# 838 ExitType(1, true)
# 839 ExitType(2, true)
# 840 ExitType(9, true)
# 841 ExitType(1, true)
# 842 ExitType(1, true)
# 843 ExitType(1, true)
# 844 ExitType(1, true)
# 845 ExitType(3, true)
# 846 ExitType(1, true)
# 848 ExitType(4, true)
# 849 ExitType(1, true)
# 851 ExitType(2, true)
# 852 ExitType(1, true)
# 853 ExitType(1, true)
# 855 ExitType(1, true)
# 856 ExitType(1, true)
# 857 ExitType(1, true)
# 858 ExitType(1, true)
# 859 ExitType(1, true)
# 860 ExitType(1, true)
# 861 ExitType(1, true)
# 862 ExitType(3, true)
# 863 ExitType(1, true)
# 864 ExitType(1, true)
# 865 ExitType(1, true)
# 867 ExitType(1, true)
# 869 ExitType(1, true)
# 871 ExitType(1, true)
# 872 ExitType(17, true)
# 873 ExitType(1, true)
# 874 ExitType(2, true)
# 875 ExitType(1, true)
# 877 ExitType(1, true)
# 878 ExitType(1, true)
# 879 ExitType(1, true)
# 880 ExitType(1, true)
# 881 ExitType(4, true)
# 882 ExitType(2, true)
# 883 ExitType(1, true)
# 886 ExitType(1, true)
# 889 ExitType(1, true)
# 890 ExitType(11, true)
# 891 ExitType(1, true)
# 892 ExitType(4, true)
# 893 ExitType(1, true)
# 894 ExitType(1, true)
# 895 ExitType(1, true)
# 896 ExitType(14, true)
# 897 ExitType(1, true)
# 898 ExitType(1, true)
# 899 ExitType(1, true)
# 900 ExitType(1, true)
# 901 ExitType(3, true)
# 902 ExitType(1, true)
# 904 ExitType(1, true)
# 905 ExitType(1, true)
# 906 ExitType(1, true)
# 907 ExitType(1, true)
# 908 ExitType(1, true)
# 909 ExitType(1, true)
# 910 ExitType(3, true)
# 912 ExitType(9, true)
# 913 ExitType(6, true)
# 915 ExitType(6, true)
# 917 ExitType(1, true)
# 919 ExitType(1, true)
# 921 ExitType(1, true)
# 924 ExitType(1, true)
# 925 ExitType(2, true)
# 928 ExitType(13, true)
# 930 ExitType(3, true)
# 931 ExitType(1, true)
# 934 ExitType(1, true)
# 935 ExitType(1, true)
# 936 ExitType(1, true)
# 937 ExitType(1, true)
# 938 ExitType(2, true)
# 940 ExitType(1, true)
# 943 ExitType(2, true)
# 944 ExitType(1, true)
# 946 ExitType(1, true)
# 947 ExitType(1, true)
# 948 ExitType(1, true)
# 950 ExitType(1, true)
# 952 ExitType(5, true)
# 953 ExitType(1, true)
# 954 ExitType(3, true)
# 955 ExitType(1, true)
# 956 ExitType(3, true)
# 957 ExitType(2, true)
# 958 ExitType(1, true)
# 959 ExitType(6, true)
# 960 ExitType(1, true)
# 963 ExitType(1, true)
# 964 ExitType(1, true)
# 965 ExitType(1, true)
# 966 ExitType(1, true)
# 968 ExitType(1, true)
# 969 ExitType(1, true)
# 970 ExitType(1, true)
# 972 ExitType(1, true)
# 974 ExitType(1, true)
# 975 ExitType(2, true)
# 976 ExitType(1, true)
# 977 ExitType(1, true)
# 978 ExitType(8, true)
# 979 ExitType(1, true)
# 980 ExitType(2, true)
# 981 ExitType(1, true)
# 982 ExitType(1, true)
# 983 ExitType(5, true)
# 984 ExitType(1, true)
# 985 ExitType(9, true)
# 986 ExitType(1, true)
# 987 ExitType(4, true)
# 988 ExitType(1, true)
# 989 ExitType(1, true)
# 990 ExitType(1, true)
# 991 ExitType(1, true)
# 992 ExitType(1, true)
# 993 ExitType(1, true)
# 994 ExitType(1, true)
# 995 ExitType(1, true)
# 996 ExitType(1, true)
# 998 ExitType(1, true)
# 999 ExitType(4, true)
# 1001 ExitType(1, true)
# 1003 ExitType(1, true)
# 1004 ExitType(7, true)
# 1006 ExitType(1, true)
# 1007 ExitType(6, true)
# 1008 ExitType(1, true)
# 1010 ExitType(22, true)
# 1011 ExitType(11, true)
# 1012 ExitType(1, true)
# 1013 ExitType(1, true)
# 1014 ExitType(1, true)
# 1015 ExitType(3, true)
# 1016 ExitType(1, true)
# 1018 ExitType(1, true)
# 1020 ExitType(2, true)
# 1021 ExitType(1, true)
# 1022 ExitType(1, true)
# 1023 ExitType(9, true)
# 1024 ExitType(1, true)
# 1026 ExitType(1, true)
# 1027 ExitType(8, true)
# 1028 ExitType(8, true)
# 1029 ExitType(2, true)
# 1030 ExitType(1, true)
# 1031 ExitType(1, true)
# 1032 ExitType(1, true)
# 1033 ExitType(1, true)
# 1034 ExitType(1, true)
# 1036 ExitType(2, true)
# 1037 ExitType(1, true)
# 1039 ExitType(1, true)
# 1040 ExitType(3, true)
# 1041 ExitType(3, true)
# 1043 ExitType(2, true)
# 1044 ExitType(2, true)
# 1047 ExitType(8, true)
# 1048 ExitType(1, true)
# 1049 ExitType(1, true)
# 1051 ExitType(9, true)
# 1053 ExitType(1, true)
# 1054 ExitType(1, true)
# 1055 ExitType(1, true)
# 1056 ExitType(1, true)
# 1058 ExitType(1, true)
# 1059 ExitType(19, true)
# 1060 ExitType(6, true)
# 1061 ExitType(1, true)
# 1062 ExitType(4, true)
# 1064 ExitType(1, true)
# 1065 ExitType(2, true)
# 1066 ExitType(7, true)
# 1067 ExitType(1, true)
# 1068 ExitType(1, true)
# 1069 ExitType(1, true)
# 1070 ExitType(1, true)
# 1072 ExitType(1, true)
# 1073 ExitType(1, true)
# 1074 ExitType(1, true)
# 1075 ExitType(1, true)
# 1076 ExitType(2, true)
# 1077 ExitType(1, true)
# 1078 ExitType(3, true)
# 1079 ExitType(1, true)
# 1080 ExitType(1, true)
# 1081 ExitType(1, true)
# 1082 ExitType(1, true)
# 1084 ExitType(1, true)
# 1085 ExitType(1, true)
# 1086 ExitType(1, true)
# 1087 ExitType(2, true)
# 1088 ExitType(3, true)
# 1089 ExitType(3, true)
# 1090 ExitType(2, true)
# 1093 ExitType(5, true)
# 1096 ExitType(1, true)
# 1098 ExitType(6, true)
# 1100 ExitType(1, true)
# 1101 ExitType(1, true)
# 1102 ExitType(2, true)
# 1104 ExitType(10, true)
# 1105 ExitType(3, true)
# 1107 ExitType(1, true)
# 1108 ExitType(1, true)
# 1109 ExitType(8, true)
# 1110 ExitType(1, true)
# 1111 ExitType(1, true)
# 1112 ExitType(2, true)
# 1113 ExitType(1, true)
# 1114 ExitType(7, true)
# 1115 ExitType(1, true)
# 1116 ExitType(1, true)
# 1117 ExitType(1, true)
# 1118 ExitType(1, true)
# 1119 ExitType(1, true)
# 1120 ExitType(1, true)
# 1121 ExitType(1, true)
# 1122 ExitType(15, true)
# 1123 ExitType(9, true)
# 1125 ExitType(1, true)
# 1126 ExitType(1, true)
# 1128 ExitType(3, true)
# 1129 ExitType(1, true)
# 1130 ExitType(1, true)
# 1131 ExitType(1, true)
# 1132 ExitType(1, true)
# 1133 ExitType(1, true)
# 1134 ExitType(1, true)
# 1135 ExitType(1, true)
# 1137 ExitType(1, true)
# 1138 ExitType(3, true)
# 1140 ExitType(2, true)
# 1142 ExitType(5, true)
# 1143 ExitType(1, true)
# 1144 ExitType(1, true)
# 1145 ExitType(5, true)
# 1147 ExitType(1, true)
# 1148 ExitType(1, true)
# 1150 ExitType(1, true)
# 1151 ExitType(1, true)
# 1152 ExitType(1, true)
# 1155 ExitType(1, true)
# 1157 ExitType(1, true)
# 1158 ExitType(1, true)
# 1160 ExitType(1, true)
# 1162 ExitType(1, true)
# 1163 ExitType(1, true)
# 1164 ExitType(1, true)
# 1165 ExitType(1, true)
# 1166 ExitType(1, true)
# 1167 ExitType(4, true)
# 1169 ExitType(1, true)
# 1170 ExitType(1, true)
# 1171 ExitType(1, true)
# 1172 ExitType(1, true)
# 1174 ExitType(1, true)
# 1176 ExitType(1, true)
# 1178 ExitType(1, true)
# 1179 ExitType(1, true)
# 1180 ExitType(1, true)
# 1181 ExitType(1, true)
# 1182 ExitType(1, true)
# 1183 ExitType(5, true)
# 1185 ExitType(1, true)
# 1187 ExitType(6, true)
# 1188 ExitType(1, true)
# 1190 ExitType(1, true)
# 1191 ExitType(1, true)
# 1193 ExitType(1, true)
# 1194 ExitType(3, true)
# 1195 ExitType(1, true)
# 1196 ExitType(1, true)
# 1197 ExitType(1, true)
# 1198 ExitType(2, true)
# 1199 ExitType(1, true)
# 1200 ExitType(1, true)
# 1201 ExitType(1, true)
# 1203 ExitType(4, true)
# 1204 ExitType(12, true)
# 1206 ExitType(1, true)
# 1207 ExitType(1, true)
# 1210 ExitType(1, true)
# 1211 ExitType(1, true)
# 1212 ExitType(1, true)
# 1214 ExitType(1, true)
# 1215 ExitType(1, true)
# 1216 ExitType(1, true)
# 1218 ExitType(1, true)
# 1220 ExitType(1, true)
# 1221 ExitType(1, true)
# 1222 ExitType(1, true)
# 1223 ExitType(1, true)
# 1224 ExitType(1, true)
# 1225 ExitType(1, true)
# 1226 ExitType(1, true)
# 1227 ExitType(5, true)
# 1228 ExitType(1, true)
# 1229 ExitType(25, true)
# 1230 ExitType(1, true)
# 1232 ExitType(1, true)
# 1233 ExitType(1, true)
# 1235 ExitType(5, true)
# 1238 ExitType(1, true)
# 1239 ExitType(1, true)
# 1240 ExitType(1, true)
# 1241 ExitType(5, true)
# 1242 ExitType(1, true)
# 1247 ExitType(1, true)
# 1248 ExitType(1, true)
# 1249 ExitType(6, true)
# 1250 ExitType(1, true)
# 1252 ExitType(1, true)
# 1253 ExitType(2, true)
# 1254 ExitType(1, true)
# 1255 ExitType(1, true)
# 1259 ExitType(1, true)
# 1260 ExitType(3, true)
# 1263 ExitType(1, true)
# 1264 ExitType(3, true)
# 1266 ExitType(1, true)
# 1268 ExitType(5, true)
# 1269 ExitType(2, true)
# 1270 ExitType(2, true)
# 1273 ExitType(3, true)
# 1274 ExitType(1, true)
# 1276 ExitType(1, true)
# 1277 ExitType(1, true)
# 1278 ExitType(1, true)
# 1281 ExitType(1, true)
# 1283 ExitType(7, true)
# 1284 ExitType(1, true)
# 1285 ExitType(1, true)
# 1286 ExitType(1, true)
# 1289 ExitType(1, true)
# 1290 ExitType(1, true)
# 1291 ExitType(1, true)
# 1294 ExitType(1, true)
# 1295 ExitType(1, true)
# 1296 ExitType(1, true)
# 1297 ExitType(2, true)
# 1299 ExitType(5, true)
# 1300 ExitType(11, true)
# 1301 ExitType(1, true)
# 1302 ExitType(12, true)
# 1304 ExitType(1, true)
# 1305 ExitType(1, true)
# 1306 ExitType(1, true)
# 1307 ExitType(1, true)
# 1308 ExitType(1, true)
# 1309 ExitType(3, true)
# 1311 ExitType(1, true)
# 1312 ExitType(1, true)
# 1313 ExitType(3, true)
# 1315 ExitType(1, true)
# 1317 ExitType(16, true)
# 1318 ExitType(1, true)
# 1319 ExitType(1, true)
# 1320 ExitType(7, true)
# 1321 ExitType(1, true)
# 1322 ExitType(1, true)
# 1323 ExitType(10, true)
# 1325 ExitType(1, true)
# 1326 ExitType(1, true)
# 1327 ExitType(1, true)
# 1329 ExitType(1, true)
# 1333 ExitType(1, true)
# 1334 ExitType(3, true)
# 1335 ExitType(1, true)
# 1336 ExitType(1, true)
# 1337 ExitType(1, true)
# 1338 ExitType(5, true)
# 1339 ExitType(3, true)
# 1340 ExitType(1, true)
# 1341 ExitType(1, true)
# 1343 ExitType(2, true)
# 1344 ExitType(1, true)
# 1346 ExitType(24, true)
# 1348 ExitType(1, true)
# 1351 ExitType(1, true)
# 1352 ExitType(2, true)
# 1354 ExitType(3, true)
# 1355 ExitType(1, true)
# 1356 ExitType(1, true)
# 1357 ExitType(2, true)
# 1358 ExitType(1, true)
# 1359 ExitType(2, true)
# 1360 ExitType(1, true)
# 1361 ExitType(1, true)
# 1362 ExitType(2, true)
# 1364 ExitType(7, true)
# 1365 ExitType(2, true)
# 1366 ExitType(1, true)
# 1367 ExitType(2, true)
# 1368 ExitType(3, true)
# 1370 ExitType(1, true)
# 1371 ExitType(1, true)
# 1372 ExitType(6, true)
# 1374 ExitType(1, true)
# 1376 ExitType(1, true)
# 1377 ExitType(1, true)
# 1379 ExitType(1, true)
# 1380 ExitType(1, true)
# 1381 ExitType(5, true)
# 1382 ExitType(1, true)
# 1384 ExitType(1, true)
# 1385 ExitType(9, true)
# 1388 ExitType(1, true)
# 1389 ExitType(1, true)
# 1390 ExitType(1, true)
# 1391 ExitType(3, true)
# 1392 ExitType(1, true)
# 1393 ExitType(1, true)
# 1394 ExitType(1, true)
# 1396 ExitType(1, true)
# 1398 ExitType(1, true)
# 1399 ExitType(1, true)
# 1400 ExitType(1, true)
# 1401 ExitType(1, true)
# 1402 ExitType(1, true)
# 1403 ExitType(17, true)
# 1405 ExitType(1, true)
# 1408 ExitType(1, true)
# 1409 ExitType(1, true)
# 1410 ExitType(1, true)
# 1411 ExitType(1, true)
# 1412 ExitType(1, true)
# 1413 ExitType(2, true)
# 1414 ExitType(1, true)
# 1415 ExitType(2, true)
# 1418 ExitType(1, true)
# 1419 ExitType(1, true)
# 1420 ExitType(2, true)
# 1421 ExitType(5, true)
# 1422 ExitType(8, true)
# 1423 ExitType(1, true)
# 1424 ExitType(8, true)
# 1425 ExitType(4, true)
# 1426 ExitType(1, true)
# 1427 ExitType(1, true)
# 1428 ExitType(2, true)
# 1429 ExitType(1, true)
# 1430 ExitType(1, true)
# 1431 ExitType(1, true)
# 1432 ExitType(3, true)
# 1433 ExitType(2, true)
# 1434 ExitType(2, true)
# 1435 ExitType(1, true)
# 1436 ExitType(1, true)
# 1437 ExitType(1, true)
# 1438 ExitType(8, true)
# 1439 ExitType(2, true)
# 1440 ExitType(1, true)
# 1443 ExitType(1, true)
# 1444 ExitType(1, true)
# 1445 ExitType(1, true)
# 1446 ExitType(11, true)
# 1448 ExitType(1, true)
# 1451 ExitType(11, true)
# 1452 ExitType(6, true)
# 1453 ExitType(1, true)
# 1454 ExitType(1, true)
# 1456 ExitType(1, true)
# 1457 ExitType(1, true)
# 1458 ExitType(24, true)
# 1459 ExitType(11, true)
# 1460 ExitType(3, true)
# 1463 ExitType(1, true)
# 1464 ExitType(1, true)
# 1466 ExitType(1, true)
# 1467 ExitType(23, true)
# 1471 ExitType(4, true)
# 1473 ExitType(1, true)
# 1474 ExitType(6, true)
# 1476 ExitType(1, true)
# 1477 ExitType(1, true)
# 1479 ExitType(1, true)
# 1480 ExitType(1, true)
# 1481 ExitType(1, true)
# 1482 ExitType(1, true)
# 1483 ExitType(1, true)
# 1484 ExitType(1, true)
# 1485 ExitType(2, true)
# 1486 ExitType(1, true)
# 1487 ExitType(1, true)
# 1488 ExitType(1, true)
# 1489 ExitType(1, true)
# 1490 ExitType(1, true)
# 1492 ExitType(2, true)
# 1493 ExitType(1, true)
# 1494 ExitType(1, true)
# 1495 ExitType(1, true)
# 1496 ExitType(1, true)
# 1497 ExitType(14, true)
# 1498 ExitType(1, true)
# 1499 ExitType(1, true)
# 1500 ExitType(1, true)
# 1501 ExitType(1, true)
# 1502 ExitType(11, true)
# 1504 ExitType(3, true)
# 1505 ExitType(3, true)
# 1506 ExitType(10, true)
# 1507 ExitType(1, true)
# 1509 ExitType(1, true)
# 1510 ExitType(1, true)
# 1511 ExitType(1, true)
# 1512 ExitType(1, true)
# 1513 ExitType(1, true)
# 1514 ExitType(1, true)
# 1515 ExitType(1, true)
# 1516 ExitType(1, true)
# 1517 ExitType(1, true)
# 1519 ExitType(1, true)
# 1521 ExitType(1, true)
# 1523 ExitType(9, true)
# 1527 ExitType(1, true)
# 1528 ExitType(1, true)
# 1529 ExitType(11, true)
# 1531 ExitType(3, true)
# 1532 ExitType(1, true)
# 1533 ExitType(10, true)
# 1534 ExitType(1, true)
# 1535 ExitType(1, true)
# 1536 ExitType(1, true)
# 1537 ExitType(1, true)
# 1538 ExitType(1, true)
# 1541 ExitType(7, true)
# 1542 ExitType(1, true)
# 1543 ExitType(1, true)
# 1544 ExitType(1, true)
# 1546 ExitType(3, true)
# 1547 ExitType(1, true)
# 1548 ExitType(12, true)
# 1549 ExitType(2, true)
# 1550 ExitType(1, true)
# 1552 ExitType(1, true)
# 1554 ExitType(1, true)
# 1555 ExitType(1, true)
# 1556 ExitType(1, true)
# 1557 ExitType(5, true)
# 1558 ExitType(3, true)
# 1559 ExitType(2, true)
# 1560 ExitType(1, true)
# 1563 ExitType(1, true)
# 1564 ExitType(1, true)
# 1565 ExitType(3, true)
# 1566 ExitType(5, true)
# 1567 ExitType(1, true)
# 1568 ExitType(6, true)
# 1570 ExitType(1, true)
# 1571 ExitType(1, true)
# 1572 ExitType(2, true)
# 1573 ExitType(1, true)
# 1574 ExitType(1, true)
# 1575 ExitType(1, true)
# 1576 ExitType(1, true)
# 1578 ExitType(2, true)
# 1579 ExitType(1, true)
# 1581 ExitType(2, true)
# 1582 ExitType(1, true)
# 1583 ExitType(1, true)
# 1584 ExitType(1, true)
# 1585 ExitType(6, true)
# 1586 ExitType(1, true)
# 1587 ExitType(1, true)
# 1588 ExitType(1, true)
# 1590 ExitType(1, true)
# 1591 ExitType(16, true)
# 1592 ExitType(1, true)
# 1597 ExitType(1, true)
# 1598 ExitType(1, true)
# 1600 ExitType(1, true)
